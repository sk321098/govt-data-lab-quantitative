# %%
#UPDATE this cell with your data source + Dictionary/Codebook
#data source: https://think.cs.vt.edu/corgis/csv/school_scores/
#data dictionary: https://think.cs.vt.edu/corgis/csv/school_scores/

# %%
#import libraries
import pandas as pd
import math
import matplotlib
import numpy as np

# %%
#name file path and choose appropriate cell to execute
file = 'school_scores.csv'

# %%
#read data from XLS and print head
df = pd.read_csv('school_scores.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of      Year State.Code     State.Name  Total.Math  Total.Test-takers  \
# 0    2005         AL        Alabama         559               3985
# 1    2005         AK         Alaska         519               3996
# 2    2005         AZ        Arizona         530              18184
# 3    2005         AR       Arkansas         552               1600
# 4    2005         CA     California         522             186552
# ..    ...        ...            ...         ...                ...
# 572  2015         VA       Virginia         517              59621
# 573  2015         WA     Washington         511              44423
# 574  2015         WV  West Virginia         500               2501
# 575  2015         WI      Wisconsin         606               2277
# 576  2015         WY        Wyoming         587                181
#
#      Total.Verbal  Academic Subjects.Arts/Music.Average GPA  \
# 0             567                                      3.92
# ...

# %%
#print first five rows of dataset
print(df.head())
# Out:
#    Year State.Code  State.Name  Total.Math  Total.Test-takers  Total.Verbal  \
# 0  2005         AL     Alabama         559               3985           567
# 1  2005         AK      Alaska         519               3996           523
# 2  2005         AZ     Arizona         530              18184           526
# 3  2005         AR    Arkansas         552               1600           563
# 4  2005         CA  California         522             186552           504
#
#    Academic Subjects.Arts/Music.Average GPA  \
# 0                                      3.92
# 1                                      3.76
# 2                                      3.85
# 3                                      3.90
# 4                                      3.76
#
#    Academic Subjects.Arts/Music.Average Years  \
# 0                                         2.2
# 1                                         1.9
# 2                                         2.1
# 3                                         2.2
# ...

# %%
#print list of column names
print(list(df))
print(len(df))
print(len(list(df)))
# Out:
# ['Year', 'State.Code', 'State.Name', 'Total.Math', 'Total.Test-takers', 'Total.Verbal', 'Academic Subjects.Arts/Music.Average GPA', 'Academic Subjects.Arts/Music.Average Years', 'Academic Subjects.English.Average GPA', 'Academic Subjects.English.Average Years', 'Academic Subjects.Foreign Languages.Average GPA', 'Academic Subjects.Foreign Languages.Average Years', 'Academic Subjects.Mathematics.Average GPA', 'Academic Subjects.Mathematics.Average Years', 'Academic Subjects.Natural Sciences.Average GPA', 'Academic Subjects.Natural Sciences.Average Years', 'Academic Subjects.Social Sciences/History.Average GPA', 'Academic Subjects.Social Sciences/History.Average Years', 'Family Income.Between 20-40k.Math', 'Family Income.Between 20-40k.Test-takers', 'Family Income.Between 20-40k.Verbal', 'Family Income.Between 40-60k.Math', 'Family Income.Between 40-60k.Test-takers', 'Family Income.Between 40-60k.Verbal', 'Family Income.Between 60-80k.Math', 'Family Income.Between 60-80k.Test-takers', '
# ...

# %%
#output frequency table of chosen column in dataset
col = 'Family Income.Between 20-40k.Math' #<-edit this value! column name as it appears in dataframe
col_name = 'Math scores from 20-40k income households' #<-edit this value! descriptive name for column
freq = df[col].value_counts().rename_axis(col_name).reset_index(name='freq')
freq = freq.sort_values(by = col_name)
print(freq)
# Out:
#      Math scores from 20-40k income households  freq
# 123                                          0     1
# 122                                        354     1
# 82                                         377     3
# 118                                        380     1
# 161                                        383     1
# ..                                         ...   ...
# 142                                        603     1
# 155                                        605     1
# 151                                        606     1
# 167                                        608     1
# 140                                        643     1
#
# [170 rows x 2 columns]

# %%
#replace codes with descriptive labels
#if your dataframe already has descriptive labels, you don't need to run this cell
#codebook = [['1', 'Married Couple Family'], #<- if appropriate, replace these values based on codebook or data dictionary for your dataset
          #  ['2', 'Male Reference Person'], 
          #  ['3', 'Female Reference Person']]
#loops through label codes and replaces them in frequency table
for lbl in codebook:
    #Use line below if codes are stored as integers
    freq[col_name] = freq[col_name].replace(int(lbl[0]), lbl[1])



#prints updated frequency table
print(freq)
# Out:
#      Math scores from 20-40k income households  freq
# 123                                          0     1
# 122                                        354     1
# 82                                         377     3
# 118                                        380     1
# 161                                        383     1
# ..                                         ...   ...
# 142                                        603     1
# 155                                        605     1
# 151                                        606     1
# 167                                        608     1
# 140                                        643     1
#
# [170 rows x 2 columns]

# %%
#create frequency chart
ax = freq.plot.barh(x='freq', y=col_name, rot=0, figsize = (50,50))

# %%
#calculate mean of a column
quant_col = 'Family Income.Between 20-40k.Math'
mean = df[quant_col].mean()
print(mean)

median = df[quant_col].median()
print(median)

standard_deviation = df[quant_col].std()
print(standard_deviation)
# Out:
# 500.23916811091857
# 495.0
# 48.456649347364355

# %%
#output frequency table of chosen column in dataset
col = 'Family Income.Between 80-100k.Math' #<-edit this value! column name as it appears in dataframe
col_name = 'Math scores from 80-100k income households' #<-edit this value! descriptive name for column
freq = df[col].value_counts().rename_axis(col_name).reset_index(name='freq')
freq = freq.sort_values(by = col_name)
print(freq)
# Out:
#      Math scores from 80-100k income households  freq
# 124                                         398     1
# 152                                         405     1
# 116                                         420     1
# 121                                         435     1
# 144                                         442     1
# ..                                          ...   ...
# 148                                         631     1
# 136                                         634     1
# 110                                         635     1
# 131                                         644     1
# 140                                         646     1
#
# [153 rows x 2 columns]

# %%
#replace codes with descriptive labels
#if your dataframe already has descriptive labels, you don't need to run this cell
#codebook = [['1', 'Married Couple Family'], #<- if appropriate, replace these values based on codebook or data dictionary for your dataset
          #  ['2', 'Male Reference Person'], 
          #  ['3', 'Female Reference Person']]
#loops through label codes and replaces them in frequency table
for lbl in codebook:
    #Use line below if codes are stored as integers
    freq[col_name] = freq[col_name].replace(int(lbl[0]), lbl[1])



#prints updated frequency table
print(freq)
# Out:
#      Math scores from 80-100k income households  freq
# 124                                         398     1
# 152                                         405     1
# 116                                         420     1
# 121                                         435     1
# 144                                         442     1
# ..                                          ...   ...
# 148                                         631     1
# 136                                         634     1
# 110                                         635     1
# 131                                         644     1
# 140                                         646     1
#
# [153 rows x 2 columns]

# %%
#create frequency chart
ax = freq.plot.barh(x='freq', y=col_name, rot=0, figsize = (50,50))

# %%
#calculate mean of a column
quant_col = 'Family Income.Between 80-100k.Math'
mean = df[quant_col].mean()
print(mean)

median = df[quant_col].median()
print(median)

standard_deviation = df[quant_col].std()
print(standard_deviation)
# Out:
# 547.0554592720971
# 539.0
# 38.36914598181429
